# %% [markdown]
# <a href="https://colab.research.google.com/github/sineltatyana/sineltatyana/blob/main/untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.DataFrame({'x':[1,2,3],'y':[2,4,1]})

# %%
df
# Out:
#    x  y
# 0  1  2
# 1  2  4
# 2  3  1

# %%
df.drop(1,axis=0,inplace=True)
axis=0

# %%
df
# Out:
#    x  y
# 0  1  2
# 2  3  1

# %%
del df['x']#
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'x'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.reset_index(drop=True)
# Out:
#    x  y
# 0  1  2
# 1  3  1

# %%
df1=pd.DataFrame({"x":[1,3,2,],"y":[2,4,1]})
df2=pd.DataFrame({"x":[3,1,2,],"y":[0,2,2]})
print(df1>=df2)
# Out:
#        x      y
# 0  False   True
# 1   True   True
# 2   True  False

# %%
df1[df1>1]
# Out:
#      x    y
# 0  NaN  2.0
# 1  3.0  4.0
# 2  2.0  NaN

# %%
df2[(df2<2)&(df2>0)]
# Out:
#      x   y
# 0  NaN NaN
# 1  1.0 NaN
# 2  NaN NaN

# %%
df2[(df2<1)|(df2>2)]
# Out:
#      x    y
# 0  3.0  0.0
# 1  NaN  NaN
# 2  NaN  NaN

# %%
df2.isnull()
# Out:
#        x      y
# 0  False  False
# 1  False  False
# 2  False  False

# %%
data={"Имя":["Anna","Boris",None,"Djon"],
      "Возраст":[25,30,28,None]}
df=pd.DataFrame(data)

# %%
df
# Out:
#      Имя  Возраст
# 0   Anna     25.0
# 1  Boris     30.0
# 2   None     28.0
# 3   Djon      NaN

# %%
x=df.isnull()

# %%
df.isnull().loc[x["Имя"]==True]
# Out:
#     Имя  Возраст
# 2  True    False

# %%
data={"Цвет":["Красный","Синий"]}
df=pd.DataFrame(data)
df
# Out:
#       Цвет
# 0  Красный
# 1    Синий

# %%
from pandas.tseries.frequencies import unique
unique_colors=dfХ[Цвет]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-13d4887ad436> in <cell line: 2>()
#       1 from pandas.tseries.frequencies import unique
# ----> 2 unique_colors=dfХ[Цвет]
#
# NameError: name 'dfХ' is not defined
